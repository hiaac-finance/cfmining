# %%
import copy
import pandas as pd
import numpy as np
import sys
sys.path.append("../")

from cfmining.algorithms import MAPOFCEM
from cfmining.predictors import GeneralClassifier_Shap, GeneralClassifier
from cfmining.action_set import ActionSet
from cfmining.baselines import Bruteforce, MAPOCAM, Nice, Dice
from cfmining.criteria import *

from experiments_helper import run_experiments, format_df_table, summarize_results, get_data_model, get_action_set


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
SEED = 0

# %%
max_changes = 3
for dataset_name in [
    "german_cat",
    "taiwan_cat",
    "adult_cat"
    ]:
    dataset, X_train, Y_train, model, outlier_detection, individuals = get_data_model(dataset_name, "LGBMClassifier")
    individuals = individuals.sample(n = 50, random_state=SEED)
    outlier_detection.contamination = dataset.outlier_contamination
    action_set = get_action_set(dataset, X_train, default_step_size=0.05)

    model_wrap = GeneralClassifier_Shap(
        model,
        outlier_detection,
        X_train,
        shap_explainer="permutation",
        categorical_features=dataset.categoric_features,
    )
    categorical_features_bool = [col in dataset.categoric_features for col in X_train.columns]


    # setting multiple criteria
    range_calc = RangeCalculator(action_set)
    perc_calc = PercentileCalculator(action_set = action_set)
    def compare_call(pivot):
        criteria_list = [
            MaxDistCriterion(
                pivot,
                range_calc,
                categorical_features_bool,
            ),
            NumberChangesCriterion(pivot),
            PercentileCriterion(
                pivot,
                perc_calc,
            ),
            CategoricDistCriterion(pivot, categorical_features_bool)
        ]
        return MultiCriterion(criteria_list, pivot)
    
    method = MAPOFCEM(
        action_set = action_set,
        classifier = model_wrap,
        compare = compare_call,
        max_changes = max_changes,
        outlier_contamination = dataset.outlier_contamination,
        categorical_features=dataset.categoric_features,
        estimate_outlier=True,
        time_limit=np.inf,
    )

    run_experiments(
        method,
        individuals=individuals,
        model=model_wrap,
        output_file=f"../results/lgbm/{dataset}/mapofcem_tree_multi.csv"
    );
# Out:
# PermutationExplainer explainer: 101it [00:13,  1.98it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [21:54<00:00, 26.29s/it]
# PermutationExplainer explainer: 101it [00:23,  2.47it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [06:23<00:00,  7.68s/it]
# PermutationExplainer explainer: 101it [00:35,  2.01it/s]
#  76%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                      | 38/50 [8:15:02<2:36:19, 781.64s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 52
#      39     return MultiCriterion(criteria_list, pivot)
#      41 method = MAPOFCEM(
#      42     action_set = action_set,
#      43     classifier = model_wrap,
#    (...)
#      49     time_limit=np.inf,
#      50 )
# ---> 52 run_experiments(
#      53     method,
#      54     individuals=individuals,
#      55     model=model_wrap,
#      56     output_file=f"../results/lgbm/{dataset}/mapofcem_tree_multi.csv"
#      57 );
#
# File /work/giovani.valdrighi/cfmining/notebooks/experiments_helper.py:83, in run_experiments(method, individuals, model, output_file, n_jobs)
#      81     pass
#      82 start = time.time()
# ---> 83 method.fit(individual.values)
#      84 end = time.time()
#      86 solutions = method.solutions
#
# File /work/giovani.valdrighi/cfmining/notebooks/../cfmining/algorithms.py:780, in MAPOFCEM.fit(self, pivot)
#     778 while len(self.calls) > 0 and time.time() - start < self.time_limit:
#     779     _, call = self.calls.popitem()
# --> 780     self.find_candidates(*call)
#     782 self.solutions = [s.tolist() for s in self.solutions]
#     783 return self
#
# File /work/giovani.valdrighi/cfmining/notebooks/../cfmining/algorithms.py:724, in MAPOFCEM.find_candidates(self, solution, size, changes)
#     720         max_prob = self.clf.estimate_predict_max(
#     721             new_solution, open_vars, self.max_changes - new_changes
#     722         )
#     723     else:
# --> 724         max_prob = self.clf.predict_max(
#     725             new_solution, open_vars, self.max_changes - new_changes
#     726         )
#     728 # If max probability will be lower than the threshold, continue
#     729 if max_prob < self.clf.threshold - self.eps:
#
# File /work/giovani.valdrighi/cfmining/notebooks/../cfmining/predictors.py:405, in GeneralClassifier_Shap.predict_max(self, value, open_vars, n_changes)
#     402 """Calculates probability of achieving desired classification."""
#     404 if self.method_predict_max == "shap":
# --> 405     shap_individual = self.shap_explanation(tuple(value))
#     406     prob = self.predict_proba(value)
#     408     if n_changes is not None:
#
# File /work/giovani.valdrighi/cfmining/notebooks/../cfmining/predictors.py:389, in GeneralClassifier_Shap.shap_explanation(self, value)
#     387 """Calculates the shap explanation for a specific sample."""
#     388 value = pd.DataFrame(data=[value], columns=self.feature_names)
# --> 389 return self.explainer(value, **self.exp_kwargs)[0].values
#
# File /usr/local/lib/python3.10/dist-packages/shap/explainers/_permutation.py:77, in PermutationExplainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args)
#      74 def __call__(self, *args, max_evals=500, main_effects=False, error_bounds=False, batch_size="auto",
#      75              outputs=None, silent=False):
#      76     """Explain the output of the model on the given arguments."""
# ---> 77     return super().__call__(
#      78         *args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds, batch_size=batch_size,
#      79         outputs=outputs, silent=silent
#      80     )
#
# File /usr/local/lib/python3.10/dist-packages/shap/explainers/_explainer.py:266, in Explainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     264     feature_names = [[] for _ in range(len(args))]
#     265 for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__+" explainer", silent):
# --> 266     row_result = self.explain_row(
#     267         *row_args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
#     268         batch_size=batch_size, outputs=outputs, silent=silent, **kwargs
#     269     )
#     270     values.append(row_result.get("values", None))
#     271     output_indices.append(row_result.get("output_indices", None))
#
# File /usr/local/lib/python3.10/dist-packages/shap/explainers/_permutation.py:133, in PermutationExplainer.explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *row_args)
#     130     i += 1
#     132 # evaluate the masked model
# --> 133 outputs = fm(masks, zero_index=0, batch_size=batch_size)
#     135 if row_values is None:
#     136     row_values = np.zeros((len(fm),) + outputs.shape[1:])
#
# File /usr/local/lib/python3.10/dist-packages/shap/utils/_masked_model.py:60, in MaskedModel.__call__(self, masks, zero_index, batch_size)
#      58 if len(masks.shape) == 1:
#      59     if getattr(self.masker, "supports_delta_masking", False):
# ---> 60         return self._delta_masking_call(masks, zero_index=zero_index, batch_size=batch_size)
#      62     # we need to convert from delta masking to a full masking call because we were given a delta masking
#      63     # input but the masker does not support delta masking
#      64     else:
#      65         full_masks = np.zeros((int(np.sum(masks >= 0)), self._masker_cols), dtype=bool)
#
# File /usr/local/lib/python3.10/dist-packages/shap/utils/_masked_model.py:206, in MaskedModel._delta_masking_call(self, masks, zero_index, batch_size)
#     203     batch_positions[i+1] = batch_positions[i] + num_varying_rows[i]
#     205 # joined_masked_inputs = self._stack_inputs(all_masked_inputs)
# --> 206 outputs = self.model(*subset_masked_inputs)
#     207 _assert_output_input_match(subset_masked_inputs, outputs)
#     209 if self.linearize_link and self.link != links.identity and self._linearizing_weights is None:
#
# File /usr/local/lib/python3.10/dist-packages/shap/models/_model.py:21, in Model.__call__(self, *args)
#      20 def __call__(self, *args):
# ---> 21     out = self.inner_model(*args)
#      22     is_tensor = safe_isinstance(out, "torch.Tensor")
#      23     out = out.cpu().detach().numpy() if is_tensor else np.array(out)
#
# File /work/giovani.valdrighi/cfmining/notebooks/../cfmining/predictors.py:240, in GeneralClassifier_Shap.__init__.<locals>.predict_proba_aux(x)
#     238         x = x.reshape(1, -1)
#     239     x = pd.DataFrame(data=x, columns=X.columns)
# --> 240 return self.clf.predict_proba(x)[:, 1]
#
# File /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py:547, in Pipeline.predict_proba(self, X, **predict_proba_params)
#     545 for _, name, transform in self._iter(with_final=False):
#     546     Xt = transform.transform(Xt)
# --> 547 return self.steps[-1][1].predict_proba(Xt, **predict_proba_params)
#
# File /usr/local/lib/python3.10/dist-packages/lightgbm/sklearn.py:1253, in LGBMClassifier.predict_proba(self, X, raw_score, start_iteration, num_iteration, pred_leaf, pred_contrib, validate_features, **kwargs)
#    1241 def predict_proba(
#    1242     self,
#    1243     X: _LGBM_ScikitMatrixLike,
#    (...)
#    1250     **kwargs: Any
#    1251 ):
#    1252     """Docstring is set after definition, using a template."""
# -> 1253     result = super().predict(
#    1254         X=X,
#    1255         raw_score=raw_score,
#    1256         start_iteration=start_iteration,
#    1257         num_iteration=num_iteration,
#    1258         pred_leaf=pred_leaf,
#    1259         pred_contrib=pred_contrib,
#    1260         validate_features=validate_features,
#    1261         **kwargs
#    1262     )
#    1263     if callable(self._objective) and not (raw_score or pred_leaf or pred_contrib):
#    1264         _log_warning("Cannot compute class probabilities or labels "
#    1265                      "due to the usage of customized objective function.\n"
#    1266                      "Returning raw scores instead.")
#
# File /usr/local/lib/python3.10/dist-packages/lightgbm/sklearn.py:961, in LGBMModel.predict(self, X, raw_score, start_iteration, num_iteration, pred_leaf, pred_contrib, validate_features, **kwargs)
#     958 predict_params = _choose_param_value("num_threads", predict_params, self.n_jobs)
#     959 predict_params["num_threads"] = self._process_n_jobs(predict_params["num_threads"])
# --> 961 return self._Booster.predict(  # type: ignore[union-attr]
#     962     X, raw_score=raw_score, start_iteration=start_iteration, num_iteration=num_iteration,
#     963     pred_leaf=pred_leaf, pred_contrib=pred_contrib, validate_features=validate_features,
#     964     **predict_params
#     965 )
#
# File /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:4453, in Booster.predict(self, data, start_iteration, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, validate_features, **kwargs)
#    4451     else:
#    4452         num_iteration = -1
# -> 4453 return predictor.predict(
#    4454     data=data,
#    4455     start_iteration=start_iteration,
#    4456     num_iteration=num_iteration,
#    4457     raw_score=raw_score,
#    4458     pred_leaf=pred_leaf,
#    4459     pred_contrib=pred_contrib,
#    4460     data_has_header=data_has_header,
#    4461     validate_features=validate_features
#    4462 )
#
# File /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:1159, in _InnerPredictor.predict(self, data, start_iteration, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, validate_features)
#    1152     preds, nrow = self.__pred_for_csc(
#    1153         csc=data,
#    1154         start_iteration=start_iteration,
#    1155         num_iteration=num_iteration,
#    1156         predict_type=predict_type
#    1157     )
#    1158 elif isinstance(data, np.ndarray):
# -> 1159     preds, nrow = self.__pred_for_np2d(
#    1160         mat=data,
#    1161         start_iteration=start_iteration,
#    1162         num_iteration=num_iteration,
#    1163         predict_type=predict_type
#    1164     )
#    1165 elif _is_pyarrow_table(data):
#    1166     preds, nrow = self.__pred_for_pyarrow_table(
#    1167         table=data,
#    1168         start_iteration=start_iteration,
#    1169         num_iteration=num_iteration,
#    1170         predict_type=predict_type
#    1171     )
#
# File /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:1306, in _InnerPredictor.__pred_for_np2d(self, mat, start_iteration, num_iteration, predict_type)
#    1304     return preds, nrow
#    1305 else:
# -> 1306     return self.__inner_predict_np2d(
#    1307         mat=mat,
#    1308         start_iteration=start_iteration,
#    1309         num_iteration=num_iteration,
#    1310         predict_type=predict_type,
#    1311         preds=None
#    1312     )
#
# File /usr/local/lib/python3.10/dist-packages/lightgbm/basic.py:1259, in _InnerPredictor.__inner_predict_np2d(self, mat, start_iteration, num_iteration, predict_type, preds)
#    1257     raise ValueError("Wrong length of pre-allocated predict array")
#    1258 out_num_preds = ctypes.c_int64(0)
# -> 1259 _safe_call(_LIB.LGBM_BoosterPredictForMat(
#    1260     self._handle,
#    1261     ptr_data,
#    1262     ctypes.c_int(type_ptr_data),
#    1263     ctypes.c_int32(mat.shape[0]),
#    1264     ctypes.c_int32(mat.shape[1]),
#    1265     ctypes.c_int(_C_API_IS_ROW_MAJOR),
#    1266     ctypes.c_int(predict_type),
#    1267     ctypes.c_int(start_iteration),
#    1268     ctypes.c_int(num_iteration),
#    1269     _c_str(self.pred_parameter),
#    1270     ctypes.byref(out_num_preds),
#    1271     preds.ctypes.data_as(ctypes.POINTER(ctypes.c_double))))
#    1272 if n_preds != out_num_preds.value:
#    1273     raise ValueError("Wrong length for predict results")
#
# KeyboardInterrupt:

# %%
for dataset_name in [
    "german_cat", 
    "taiwan_cat", 
    "adult_cat"
    ]:
    dataset, X_train, Y_train, model, outlier_detection, individuals = get_data_model(dataset_name, "LGBMClassifier")
    individuals = individuals.sample(n = 50, random_state=SEED)
    outlier_detection.contamination = dataset.outlier_contamination

    # get number of solutions of mapofcem
    #results_cur = pd.read_csv(f"../results/lgbm/{dataset_name}/mapofcem_tree_multi.csv")
    #results_cur = summarize_results(results_cur, dataset_name)
    #n_cfs = results_cur.n_solutions.max()
    n_cfs = 5

    model_wrap = GeneralClassifier(
        model,
        outlier_detection,
        X_train,
    )

    method = Dice(
        X_train.astype(float),
        Y_train,
        model,
        n_cfs = n_cfs,
        mutable_features = dataset.mutable_features,
        continuous_features = dataset.continuous_features,
    )

    run_experiments(
        method,
        individuals = individuals,
        model = model_wrap,
        output_file=f"../results/mlp/{dataset_name}/dice.csv"
    )
