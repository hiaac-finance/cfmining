# %%
import json
import os
import copy
import numpy as np
import pandas as pd
from tqdm import tqdm
import time
import sys
sys.path.append("../")

from cfmining.algorithms import MAPOFCEM
from cfmining.predictors import GeneralClassifier_Shap, MonotoneClassifier
from cfmining.action_set import ActionSet
from cfmining.utils import get_data_model, FakeOutlierDetection
from cfmining.baselines import Bruteforce, MAPOCAM, Nice, Dice
import cfmining.algorithms as algs


# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
SEED = 0

# %% [markdown]
# ## Helper

# %%
def run_experiments(
        method,
        individuals, 
        model, 
        output_file = None,
    ):
    results = []

    if not output_file is None:
        folder = "/".join(output_file.split("/")[:-1])
        if not os.path.exists(folder):
            os.makedirs(folder, exist_ok = True)

    for i in tqdm(range(len(individuals))):
        individual = individuals.iloc[i]
        try:
            model.clear_cache()
        except:
            pass
        start = time.time()
        method.fit(individual.values)
        end = time.time()

        solutions = method.solutions
        
        results.append({
            "individual" : individual.values.tolist(),
            "prob" : model.predict_proba(individual.values),
            "time" : end - start,
            "n_solutions" : len(method.solutions),
            "solutions" : solutions,
        })

        if output_file is not None:
            pd.DataFrame(results).to_csv(output_file, index=False)

        

    results = pd.DataFrame(results)
    if output_file is not None:
        results.to_csv(output_file, index=False)
    else:
        return results

# %% [markdown]
# ## German

# %%
X_train, Y_train, model, outlier_detection, individuals = get_data_model("german", "LogisticRegression")
individuals = individuals.sample(n = 50, random_state=SEED)

# %%
not_mutable_features = ['Age', 'OwnsHouse', 'isMale', 'JobClassIsSkilled', 'Single', 'ForeignWorker', 'RentsHouse']
mutable_features = [feat for feat in X_train.columns if feat not in not_mutable_features]
continuous_features = ['Age', 'LoanDuration', 'LoanAmount', 'LoanRateAsPercentOfIncome','YearsAtCurrentHome']
categoric_features = [col for col in X_train.columns if col not in continuous_features]

action_set = ActionSet(X = X_train, default_step_size = 0.1, mutable_features = mutable_features)
model_shap = MonotoneClassifier(
    model, 
    FakeOutlierDetection(),
    X_train, 
    threshold = 0.5
)

# %%
method = MAPOFCEM(
    action_set = action_set,
    classifier = model_shap,
    compare = "lp",
    max_changes = 3,
    estimate_proba_max=False,
    estimate_outlier=False   
)

# %%
def prof_function():
    method.fit(individuals.values[0, :])

# %%
# %lprun -f MAPOFCEM.find_candidates prof_function()
# Out:
# Timer unit: 1e-09 s
#
# Total time: 16.4859 s
# File: /work/giovani.valdrighi/cfmining/notebooks/../cfmining/algorithms.py
# Function: find_candidates at line 671
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    671                                               def find_candidates(self, solution=None, size=0, changes=0):
#    672      1174    1262335.0   1075.2      0.0          next_idx = self.sequence[size]
#    673      1174     685654.0    584.0      0.0          next_name = self.names[next_idx]
#    674
#    675                                                   # Looking for a candidate following features
#    676      4115    7436633.0   1807.2      0.0          for value in self.feas_grid[next_name]:
#    677      2941   13893641.0   4724.1      0.1              new_solution = solution.copy()
#    678      2941    3159328.0   1074.2      0.0              new_solution[next_idx] = value
#    679
#    680                                                       # If new solution is worse than any previous, stop
#    681      2941    2072202.0    704.6      0.0              if not next_name in self.categorical_features:
#    682      2941    1983408.0    674.4      0.0                  for old_sol in self.solutions:
#    683                                                               if self.compare.greater_than(new_solution, old_sol):
#    684                                                                   return
#    685
#    686                                                       # If is a solution, save it
#    687      2941        1e+10    4e+06     66.1              new_proba = self.clf.predict_proba(new_solution)
#    688      2941    5449147.0   1852.8      0.0              if new_proba >= self.clf.threshold - self.eps:
#    689                                                           # Only save if it is not an outlier
#    690
#    691                                                           outlier = self.clf.predict_outlier(new_solution) == -1
#    692
#    693                                                           if not outlier and not next_name in self.categorical_features:
#    694                                                               self.update_solutions(new_solution)
#    695                                                               return
#    696                                                           else:
#    697                                                               self.outlier_detection_counter += 1
#    698                                                               # continue
#    699
#    700      2941    1221230.0    415.2      0.0              new_size = size + 1
#    701      2941    1994297.0    678.1      0.0              if new_size >= self.pivot.size:
#    702                                                           continue
#    703
#    704                                                       # If made more changes than the limit
#    705      2941    5719257.0   1944.7      0.0              new_changes = changes + (value != self.pivot[next_idx])
#    706      2941    1835994.0    624.3      0.0              if new_changes >= self.max_changes:
#    707      1467     619865.0    422.5      0.0                  continue
#    708
#    709      2948   48834489.0  16565.3      0.3              open_vars = [
#    710      1474    1479694.0   1003.9      0.0                  x for x in self.sequence[new_size:] if x in self.mutable_features
#    711                                                       ]
#    712
#    713                                                       # Calculate max probability of solution
#    714      1474     429626.0    291.5      0.0              max_prob = 1
#    715      1474    1227944.0    833.1      0.0              if hasattr(self.clf, "predict_proba_max"):
#    716      1474     494648.0    335.6      0.0                  if self.estimate_proba_max:
#    717                                                               max_prob = self.clf.estimate_predict_max(
#    718                                                                   new_solution, open_vars, self.max_changes - new_changes
#    719                                                               )
#    720                                                           else:
#    721      2948 5470741045.0    2e+06     33.2                      max_prob = self.clf.predict_proba_max(
#    722      1474     976288.0    662.3      0.0                          new_solution, open_vars, self.max_changes - new_changes
#    723                                                               )
#    724
#    725                                                       # If max probability will be lower than the threshold, continue
#    726      1474    2665894.0   1808.6      0.0              if max_prob < self.clf.threshold - self.eps:
#    727       301     258547.0    859.0      0.0                  self.prob_max_counter += 1
#    728       301     140075.0    465.4      0.0                  continue
#    729
#    730                                                       # If the partial solution is already an outlier, skip it
#    731
#    732      1173     484091.0    412.7      0.0              if self.estimate_outlier:
#    733                                                           new_solution_with_nan = new_solution.copy().astype(float)
#    734                                                           new_solution_with_nan[open_vars] = np.nan
#    735                                                           outlier = self.clf.predict_outlier(new_solution_with_nan) == -1
#    736                                                           if outlier:
#    737                                                               self.outlier_detection_counter += 1
#    738                                                               continue
#    739
#    740      1173    1122453.0    956.9      0.0              self.idd += 1
#    741      1173   13690009.0  11670.9      0.1              self.calls[(new_proba, self.idd)] = [
#    742      1173     327602.0    279.3      0.0                  new_solution,
#    743      1173     294608.0    251.2      0.0                  new_size,
#    744      1173     229493.0    195.6      0.0                  new_changes,
#    745                                                       ]

# %%
method = MAPOFCEM(
    action_set = action_set,
    classifier = model_shap,
    compare = "percentile",
    max_changes = 3,
    estimate_proba_max=False,
    estimate_outlier=False   
)
def prof_function():
    method.fit(individuals.values[0, :])

# %%
# %lprun -f MAPOFCEM.find_candidates prof_function()
# Out:
# Timer unit: 1e-09 s
#
# Total time: 16.3681 s
# File: /work/giovani.valdrighi/cfmining/notebooks/../cfmining/algorithms.py
# Function: find_candidates at line 671
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    671                                               def find_candidates(self, solution=None, size=0, changes=0):
#    672      1174    1254159.0   1068.3      0.0          next_idx = self.sequence[size]
#    673      1174     681498.0    580.5      0.0          next_name = self.names[next_idx]
#    674
#    675                                                   # Looking for a candidate following features
#    676      4115    7339197.0   1783.5      0.0          for value in self.feas_grid[next_name]:
#    677      2941   11468274.0   3899.4      0.1              new_solution = solution.copy()
#    678      2941    2931963.0    996.9      0.0              new_solution[next_idx] = value
#    679
#    680                                                       # If new solution is worse than any previous, stop
#    681      2941    1797656.0    611.2      0.0              if not next_name in self.categorical_features:
#    682      2941    1793724.0    609.9      0.0                  for old_sol in self.solutions:
#    683                                                               if self.compare.greater_than(new_solution, old_sol):
#    684                                                                   return
#    685
#    686                                                       # If is a solution, save it
#    687      2941        1e+10    4e+06     66.1              new_proba = self.clf.predict_proba(new_solution)
#    688      2941    5202040.0   1768.8      0.0              if new_proba >= self.clf.threshold - self.eps:
#    689                                                           # Only save if it is not an outlier
#    690
#    691                                                           outlier = self.clf.predict_outlier(new_solution) == -1
#    692
#    693                                                           if not outlier and not next_name in self.categorical_features:
#    694                                                               self.update_solutions(new_solution)
#    695                                                               return
#    696                                                           else:
#    697                                                               self.outlier_detection_counter += 1
#    698                                                               # continue
#    699
#    700      2941    1223307.0    415.9      0.0              new_size = size + 1
#    701      2941    1985406.0    675.1      0.0              if new_size >= self.pivot.size:
#    702                                                           continue
#    703
#    704                                                       # If made more changes than the limit
#    705      2941    5636657.0   1916.6      0.0              new_changes = changes + (value != self.pivot[next_idx])
#    706      2941    1902617.0    646.9      0.0              if new_changes >= self.max_changes:
#    707      1467     605864.0    413.0      0.0                  continue
#    708
#    709      2948   48882657.0  16581.6      0.3              open_vars = [
#    710      1474    1376972.0    934.2      0.0                  x for x in self.sequence[new_size:] if x in self.mutable_features
#    711                                                       ]
#    712
#    713                                                       # Calculate max probability of solution
#    714      1474     430902.0    292.3      0.0              max_prob = 1
#    715      1474    1221121.0    828.4      0.0              if hasattr(self.clf, "predict_proba_max"):
#    716      1474     528114.0    358.3      0.0                  if self.estimate_proba_max:
#    717                                                               max_prob = self.clf.estimate_predict_max(
#    718                                                                   new_solution, open_vars, self.max_changes - new_changes
#    719                                                               )
#    720                                                           else:
#    721      2948 5437728468.0    2e+06     33.2                      max_prob = self.clf.predict_proba_max(
#    722      1474     971467.0    659.1      0.0                          new_solution, open_vars, self.max_changes - new_changes
#    723                                                               )
#    724
#    725                                                       # If max probability will be lower than the threshold, continue
#    726      1474    2573150.0   1745.7      0.0              if max_prob < self.clf.threshold - self.eps:
#    727       301     264754.0    879.6      0.0                  self.prob_max_counter += 1
#    728       301     137276.0    456.1      0.0                  continue
#    729
#    730                                                       # If the partial solution is already an outlier, skip it
#    731
#    732      1173     487076.0    415.2      0.0              if self.estimate_outlier:
#    733                                                           new_solution_with_nan = new_solution.copy().astype(float)
#    734                                                           new_solution_with_nan[open_vars] = np.nan
#    735                                                           outlier = self.clf.predict_outlier(new_solution_with_nan) == -1
#    736                                                           if outlier:
#    737                                                               self.outlier_detection_counter += 1
#    738                                                               continue
#    739
#    740      1173    1088449.0    927.9      0.0              self.idd += 1
#    741      1173   13446884.0  11463.7      0.1              self.calls[(new_proba, self.idd)] = [
#    742      1173     329655.0    281.0      0.0                  new_solution,
#    743      1173     290130.0    247.3      0.0                  new_size,
#    744      1173     237781.0    202.7      0.0                  new_changes,
#    745                                                       ]
